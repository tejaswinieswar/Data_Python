# %% [markdown]
# # Question 5:

# %%
import nltk
from nltk.corpus import gutenberg
a=gutenberg.fileids()
from nltk.corpus import webtext
b=webtext.fileids()
#print(b)

x=nltk.corpus.gutenberg.raw('shakespeare-caesar.txt')
y=nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')
z=nltk.corpus.gutenberg.raw('shakespeare-macbeth.txt')
p=(x+y+z)
p=p.replace('\n', " ")
o=p.lower()
v=''.join(m for m in o if (m.isalpha() or m==" ") )
#print(v)
f_s=set(v.split())
#print(f_s)

r=''
for i in b:
    h=nltk.corpus.webtext.raw(i)
    r=r+h
r=r.replace('\n', " ")
q=r.lower()
#print(q)
z=''.join(m for m in q if (m.isalpha() or m==" ") )
f_w= set(z.split())

d={}
for i in f_s:
    print(i)
    if i not in f_w and i.startswith('t'):
        #print (i)
        c=o.count(i)
        d[i]=c
s_a=sorted(d, key=d.__getitem__,reverse=True)
j=0
while(j<5):
    #print (s_a[j])
    j=j+1
# Out:
# leasure
# necessitie
# dare
# esteeme
# equiuocator
# auouches
# vnscorchd
# worthy
# gouernd
# outwardly
# bed
# by
# direnesse
# thrice
# confusd
# quietly
# orewrought
# violent
# stranger
# reuerence
# go
# harme
# own
# aside
# whatsoeuer
# denmarke
# im
# prythee
# possest
# fife
# falsely
# contaminate
# stowed
# syue
# tryall
# power
# choice
# rant
# coming
# blade
# iephta
# expect
# gore
# esile
# ladder
# inuenomed
# mightst
# kindnesse
# rowe
# treasure
# lightens
# sith
# house
# command
# wrencht
# hunters
# euer
# marriages
# passe
# carud
# driue
# eccho
# nettles
# bough
# womb
# vnmeritable
# finde
# doing
# cursing
# quarter
# appoint
# denmarkes
# auoyd
# whisper
# cic
# preparation
# caesars
# labourd
# rauens
# vnreall
# heyre
# felt
# watchd
# contriuer
# apparition
# midnight
# polon
# quartered
# interdiction
# extreamity
# assurd
# liquid
# knowledge
# ardure
# aduancd
# rosse
# carters
# speaker
# ro
# conditions
# an
# puts
# blench
# residence
# ...
